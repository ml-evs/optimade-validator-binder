# %%
URL = "https://optimade.herokuapp.com"
VERBOSITY = 1

# %%
from optimade.validator import ImplementationValidator
validator = ImplementationValidator(
    base_url=URL, 
    verbosity=VERBOSITY
)
validator.validate_implementation()
# Out:
# Testing entire implementation at https://optimade.herokuapp.com...
# ✔: https://optimade.herokuapp.com/info - received expected response: <Response [200]>.
# ✔: https://optimade.herokuapp.com/info - deserialized correctly as object of type <class 'optimade.models.responses.InfoResponse'>
# ✔: https://optimade.herokuapp.com - successfully found available entry types in baseinfo
# ✔: https://optimade.herokuapp.com/versions - received expected response: <Response [200]>.
# ✔: https://optimade.herokuapp.com/versions - `/versions` endpoint responded correctly.
# ✖: https://optimade.herokuapp.com/v123123 - _get_endpoint - failed with error
# 	ResponseError: Request to 'v123123' returned HTTP code 404 and not expected 553.
# 	Error(s):
# 	  HTTPException: Not Found (N/A)
# ✔: https://optimade.herokuapp.com/info/structures - received expected response: <Response [200]>.
# ✔: https://optimade.herokuapp.com/info/structures - deserialized correctly as object of type <class 'optimade.models.responses.EntryInfoResponse'>
# ✔: https://optimade.herokuapp.com/info/references - received expected response: <Response [200]>.
# ✔: https://optimade.herokuapp.com/info/references - deserialized correctly as object of type <class 'optimade.models.responses.EntryInfoResponse'>
# ✔: https://optimade.herokuapp.com/; checking entry info for required properties - Found all required properties in entry info for endpoint {endp}
# ✔: https://optimade.herokuapp.com/structures - received expected response: <Response [200]>.
# ✔: https://optimade.herokuapp.com/structures?page_offset=0 - received expected response: <Response [200]>.
# ✔: https://optimade.herokuapp.com - set archetypal entry for structures with ID mpf_1.
# ✔: https://optimade.herokuapp.com/; testing queries for structures->id - id passed filter tests
# ✔: https://optimade.herokuapp.com/; testing queries for structures->type - Successfully validatated type
# 2020-09-14 13:36:06,048 - optimade.validator |  WARNING: Not testing queries on field last_modified of type DataType.TIMESTAMP.
# ✔: https://optimade.herokuapp.com/; testing queries for structures->elements - elements passed filter tests
# ✔: https://optimade.herokuapp.com/; testing queries for structures->nelements - nelements passed filter tests
# ✔: https://optimade.herokuapp.com/; testing queries for structures->elements_ratios - elements_ratios passed filter tests
# ✔: https://optimade.herokuapp.com/; testing queries for structures->chemical_formula_descriptive - chemical_formula_descriptive passed filter tests
# ✔: https://optimade.herokuapp.com/; testing queries for structures->chemical_formula_reduced - chemical_formula_reduced passed filter tests
# ✔: https://optimade.herokuapp.com/; testing queries for structures->chemical_formula_anonymous - chemical_formula_anonymous passed filter tests
# ✔: https://optimade.herokuapp.com/; testing queries for structures->dimension_types - dimension_types passed filter tests
# ✔: https://optimade.herokuapp.com/; testing queries for structures->nperiodic_dimensions - nperiodic_dimensions passed filter tests
# 2020-09-14 13:36:20,301 - optimade.validator |  WARNING: Not testing queries on field lattice_vectors of type DataType.LIST with nested dictionary/list entries.
# 2020-09-14 13:36:20,302 - optimade.validator |  WARNING: Not testing queries on field cartesian_site_positions of type DataType.LIST with nested dictionary/list entries.
# ✔: https://optimade.herokuapp.com/; testing queries for structures->nsites - nsites passed filter tests
# 2020-09-14 13:36:22,802 - optimade.validator |  WARNING: Not testing queries on field species of type DataType.LIST with nested dictionary/list entries.
# ✔: https://optimade.herokuapp.com/; testing queries for structures->species_at_sites - species_at_sites passed filter tests
# 2020-09-14 13:36:23,330 - optimade.validator |  WARNING: Not testing queries on field structure_features of type DataType.LIST with nested dictionary/list entries.
# ✔: https://optimade.herokuapp.com - successfully recursed through endpoint structures.
# ✔: https://optimade.herokuapp.com/; checking entry info for required properties - Found all required properties in entry info for endpoint {endp}
# ✔: https://optimade.herokuapp.com/references - received expected response: <Response [200]>.
# ✔: https://optimade.herokuapp.com/references?page_offset=2 - received expected response: <Response [200]>.
# ✔: https://optimade.herokuapp.com - set archetypal entry for references with ID dummy/2019.
# ✔: https://optimade.herokuapp.com/; testing queries for references->id - id passed filter tests
# ✔: https://optimade.herokuapp.com/; testing queries for references->type - Successfully validatated type
# 2020-09-14 13:36:25,420 - optimade.validator |  WARNING: Not testing queries on field last_modified of type DataType.TIMESTAMP.
# 2020-09-14 13:36:25,422 - optimade.validator |  WARNING: Not testing queries on field authors of type DataType.LIST with nested dictionary/list entries.
# ✔: https://optimade.herokuapp.com/; testing queries for references->doi - doi passed filter tests
# ✔: https://optimade.herokuapp.com/; testing queries for references->journal - journal passed filter tests
# ✔: https://optimade.herokuapp.com/; testing queries for references->title - title passed filter tests
# ✔: https://optimade.herokuapp.com/; testing queries for references->year - year passed filter tests
# ✔: https://optimade.herokuapp.com - successfully recursed through endpoint references.
# ✔: https://optimade.herokuapp.com/structures?page_limit=5 - received expected response: <Response [200]>.
# ✖: http://example.org/structures?page_limit=5&page_offset=5 - _get_endpoint - failed with error
# 	Critical: unable to parse server response as JSON. JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# ✖: https://optimade.herokuapp.com - _test_page_limit - failed with error
# 	ResponseError: Unable to test endpoint page limit.
# ✔: https://optimade.herokuapp.com - Endpoint obeyed page limit of 5 by returning 5 entries.
# ✔: https://optimade.herokuapp.com/structures?page_limit=5 - deserialized correctly as object of type <class 'optimade.validator.utils.ValidatorStructureResponseMany'>
# ✔: https://optimade.herokuapp.com/structures?page_limit=5 - successfully scraped test ID from structures endpoint
# ✔: https://optimade.herokuapp.com - Meta response contained correct values for data_available and data_returned.
# ✔: https://optimade.herokuapp.com/references?page_limit=5 - received expected response: <Response [200]>.
# ✔: https://optimade.herokuapp.com - Endpoint obeyed page limit of 5 by returning 3 entries.
# ✔: https://optimade.herokuapp.com/references?page_limit=5 - deserialized correctly as object of type <class 'optimade.validator.utils.ValidatorReferenceResponseMany'>
# ✔: https://optimade.herokuapp.com/references?page_limit=5 - successfully scraped test ID from references endpoint
# ✔: https://optimade.herokuapp.com - Meta response contained correct values for data_available and data_returned.
# ✔: https://optimade.herokuapp.com/structures/mpf_1 - received expected response: <Response [200]>.
# ✔: https://optimade.herokuapp.com/structures - deserialized correctly as object of type <class 'optimade.validator.utils.ValidatorStructureResponseOne'>
# ✔: https://optimade.herokuapp.com/references/dijkstra1968 - received expected response: <Response [200]>.
# ✔: https://optimade.herokuapp.com/references - deserialized correctly as object of type <class 'optimade.validator.utils.ValidatorReferenceResponseOne'>
# ✔: https://optimade.herokuapp.com/links - received expected response: <Response [200]>.
# ✔: https://optimade.herokuapp.com/links - deserialized correctly as object of type <class 'optimade.validator.utils.ValidatorLinksResponse'>
#
#
# FAILURES
# ========
#
# ✖: https://optimade.herokuapp.com/v123123 - _get_endpoint - failed with error
# 	ResponseError: Request to 'v123123' returned HTTP code 404 and not expected 553.
# 	Error(s):
# 	  HTTPException: Not Found (N/A)
# ✖: http://example.org/structures?page_limit=5&page_offset=5 - _get_endpoint - failed with error
# 	Critical: unable to parse server response as JSON. JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# ✖: https://optimade.herokuapp.com - _test_page_limit - failed with error
# 	ResponseError: Unable to test endpoint page limit.
#
#
# Passed 37 out of 40 tests.
# Additionally passed 16 out of 16 optional tests.
